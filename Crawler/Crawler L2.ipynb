# %%
import time
import requests
def requests_view(response):
    import webbrowser
    request_url = response.url
    base_url = '<head><base href="%s">'%(request_url)
    base_url = base_url.encode()
    content = response.content.replace(b"<head>",base_url)
    tem_html = open('tmp.html','wb')
    tem_html.write(content)
    tem_html.close()
    webbrowser.open_new_tab("tmp.html") #mac fail to open

# %%
respond = requests.get("http://sz.ganji.com/zufang/pn1/")

# %%
requests_view(respond)

# %%
from lxml import etree
#html = etree.HTML(respond.content)
html = etree.HTML(respond.content.decode())

# %%
path = './/*[@class="f-main-list"]//div[contains(@class,"f-list-item ershoufang-list")]'
items = html.xpath(path)

# %%
for i in items:
    title = i.xpath('.//dd/a/@title')
    price = i.xpath('.//dd[@class="dd-item info"]/div/span/text()')
    size = i.xpath('.//dd[@class="dd-item size"]/span/text()')
    agent = i.xpath('.//dd[4]/span/span/text()')[0].split()

# %%
## Create SQLsite to store data
from sqlalchemy import create_engine
engine = create_engine('sqlite:///ganji_rential.sqlite', echo = True)

from sqlalchemy import Table,Column,Integer,String,ForeignKey  
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()
DBSession = sessionmaker(bind=engine)
session = DBSession()
class rental(Base):
    __tablename__ = "rental"
    id = Column(Integer, primary_key=True)
    title = Column(String(400))
    price = Column(String(400))
    info = Column(String(400))
    agent = Column(String(400))
    
    @classmethod
    def save(cls, data):
        session.add(data)
        session.commit()
        return data.id
        
Base.metadata.create_all(engine)
# Out:
# 2019-07-23 11:40:19,706 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-07-23 11:40:19,707 INFO sqlalchemy.engine.base.Engine ()
# 2019-07-23 11:40:19,709 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-07-23 11:40:19,710 INFO sqlalchemy.engine.base.Engine ()
# 2019-07-23 11:40:19,711 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("rental")
# 2019-07-23 11:40:19,712 INFO sqlalchemy.engine.base.Engine ()

# %%
rent = rental()
rent.title = 'title'
rent.price = 'price'
rent.info = 'info'
rent.agent = 'agent'
rent.save(rent)
# Out:
# 2019-07-23 11:40:19,720 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:19,723 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:19,723 INFO sqlalchemy.engine.base.Engine ('title', 'price', 'info', 'agent')
# 2019-07-23 11:40:19,726 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:19,730 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:19,731 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:19,732 INFO sqlalchemy.engine.base.Engine (1520,)
# 1520

# %%
base_url = "http://sz.ganji.com/zufang/pn{}"
headers = {
    #'Referer':,
    'User-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'
}

def pass_data(respond):
    html = etree.HTML(respond.content.decode())
    path = './/*[@class="f-main-list"]//div[contains(@class,"f-list-item ershoufang-list")]'
    items = html.xpath(path)
    for i in items:
        title = i.xpath('.//dd/a/@title')
        price = i.xpath('.//dd[@class="dd-item info"]/div/span/text()')
        info = i.xpath('.//dd[@class="dd-item size"]/span/text()')
        agent = i.xpath('.//dd[4]/span/span/text()')[0].split()
        rent = rental()
        rent.title = " ".join(title)
        rent.price = " ".join(price)
        rent.info = " ".join(info)
        rent.agent = " ".join(agent)
        rent.save(rent)

for num in range(71):
    re_url = base_url.format(num)
    response = requests.get(re_url, headers = headers)
    if response.status_code == 403:
        for i in range(3):
            response = requests.get(re_url, headers = headers)
            if response.status_code == 200:
                break
    if response.status_code == 200:
        pass_data(respond)
    print(re_url, "status:",response.status_code)
    time.sleep(0.5)
# Out:
# 2019-07-23 11:40:33,022 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,046 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,047 INFO sqlalchemy.engine.base.Engine ('龙华大浪 房东直租  32平单间  豪华装修  全新家私家电', '850 元/月', '1室0厅1卫 32㎡ 南向 豪华装修', '来自经纪人： 文辉物业 - 桂小英')
# 2019-07-23 11:40:33,048 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,052 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,053 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,053 INFO sqlalchemy.engine.base.Engine (1766,)
# 2019-07-23 11:40:33,056 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,056 INFO sqlalchemy.engine.base.Engine ('碧桂园品牌公寓 青年白领社区 企业可优惠 家私齐全 停车方便', '850 元/月', '1室1厅1卫 15㎡ 东南向 精装修', '来自经纪人： 碧家国际社区 - 碧家国际社区(深圳店) - 贾万磊')
# 2019-07-23 11:40:33,058 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,060 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,061 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,062 INFO sqlalchemy.engine.base.Engine (1767,)
# 2019-07-23 11:40:33,064 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,064 INFO sqlalchemy.engine.base.Engine ('整租 龙华景乐市场附近 碧桂园碧国际社区 整租拎包入住', '1080 元/月', '1室1厅1卫 26㎡ 南向 精装修', '来自经纪人： 碧家国际社区 - 碧家国际社区(深圳店) - 林佳达')
# 2019-07-23 11:40:33,065 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,069 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,070 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,071 INFO sqlalchemy.engine.base.Engine (1768,)
# 2019-07-23 11:40:33,074 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,074 INFO sqlalchemy.engine.base.Engine ('11号线马安山地铁，全新家私电器，全新公寓，交通方便', '1280 元/月', '1室0厅1卫 25㎡ 东南向 豪华装修', '来自经纪人： 前海租无忧物业 - 许锹纯')
# 2019-07-23 11:40:33,076 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,079 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,080 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,080 INFO sqlalchemy.engine.base.Engine (1769,)
# 2019-07-23 11:40:33,083 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,083 INFO sqlalchemy.engine.base.Engine ('华荣路，公交车站旁，大小单间拎包入住，停车方便，首月免租。', '1180 元/月', '1室0厅1卫 35㎡ 南向 精装修', '来自经纪人： 寓小二公寓 - 寓小二地产(深圳分行) - 杨宗盛')
# 2019-07-23 11:40:33,086 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,088 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,089 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,090 INFO sqlalchemy.engine.base.Engine (1770,)
# 2019-07-23 11:40:33,092 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,093 INFO sqlalchemy.engine.base.Engine ('龙华地铁可短租碧桂园直租 有车位家电网络齐全 精装修一房', '1100 元/月', '1室1厅1卫 37㎡ 南向 精装修', '来自经纪人： 碧家国际社区 - 碧家国际社区(深圳店) - 蒋娟')
# 2019-07-23 11:40:33,094 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,097 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,098 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,098 INFO sqlalchemy.engine.base.Engine (1771,)
# 2019-07-23 11:40:33,101 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,101 INFO sqlalchemy.engine.base.Engine ('房东招租大单间一房一厅带家私家电独立厨卫押一付一拎包入住', '950 元/月', '1室0厅1卫 25㎡ 南向 精装修', '来自经纪人： 爱之家物业 - 江姚')
# 2019-07-23 11:40:33,103 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,105 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,106 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,107 INFO sqlalchemy.engine.base.Engine (1772,)
# 2019-07-23 11:40:33,110 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,110 INFO sqlalchemy.engine.base.Engine ('龙华大浪商业中心附近豪装公寓全新全配拎包入住（直租）', '1380 元/月', '1室0厅1卫 35㎡ 南向 豪华装修', '来自经纪人： 深圳房产经纪 - 深圳房产经纪31 - 桂敏翠')
# 2019-07-23 11:40:33,112 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,115 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,116 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,116 INFO sqlalchemy.engine.base.Engine (1773,)
# 2019-07-23 11:40:33,119 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,119 INFO sqlalchemy.engine.base.Engine ('塘尾品牌公寓[090House]温馨 年轻人的港湾！', '980 元/月', '1室0厅1卫 30㎡ 南北向 精装修', '来自经纪人： 中际物业 - 汤发洋')
# 2019-07-23 11:40:33,121 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,123 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,124 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,124 INFO sqlalchemy.engine.base.Engine (1774,)
# 2019-07-23 11:40:33,127 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,128 INFO sqlalchemy.engine.base.Engine ('希林公寓龙华店公寓直租无中介拎包入住采光好交通便利华荣路', '1380 元/月', '1室0厅1卫 32㎡ 南向 豪华装修', '来自经纪人： 深圳房产经纪 - 深圳房产经纪31 - 桂敏翠')
# 2019-07-23 11:40:33,130 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,133 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,134 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,134 INFO sqlalchemy.engine.base.Engine (1775,)
# 2019-07-23 11:40:33,137 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,138 INFO sqlalchemy.engine.base.Engine ('4号线龙胜商圈，有一房一厅出租，租房还有惊喜哦', '1250 元/月', '1室1厅1卫 45㎡ 南向 精装修', '来自经纪人： 陶寓公寓 - 洪斌')
# 2019-07-23 11:40:33,139 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,142 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,143 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,143 INFO sqlalchemy.engine.base.Engine (1776,)
# 2019-07-23 11:40:33,145 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,146 INFO sqlalchemy.engine.base.Engine ('4号线龙华 清湖双地铁 汇海广场旁 南北通透 采光好大单间', '1100 元/月', '1室0厅1卫 20㎡ 东南向 精装修', '来自经纪人： 独立经纪人（龙华） - 廖哲')
# 2019-07-23 11:40:33,149 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,152 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,153 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,154 INFO sqlalchemy.engine.base.Engine (1777,)
# 2019-07-23 11:40:33,156 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,156 INFO sqlalchemy.engine.base.Engine ('11号线！看清楚！塘尾地铁口！塘尾地铁口！网红公寓1180元', '1180 元/月', '1室0厅1卫 35㎡ 南向 豪华装修', '来自经纪人： 华越物业 - 杨耀建')
# 2019-07-23 11:40:33,158 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,160 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,161 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,161 INFO sqlalchemy.engine.base.Engine (1778,)
# 2019-07-23 11:40:33,164 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,164 INFO sqlalchemy.engine.base.Engine ('龙华地铁 暑假旅游旺季主播房 全新家电 拎包入住 长租有优惠', '1300 元/月', '1室1厅1卫 36㎡ 南向 精装修', '来自经纪人： 碧家国际社区 - 碧家国际社区(深圳店) - 左建民')
# 2019-07-23 11:40:33,165 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,168 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,169 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,170 INFO sqlalchemy.engine.base.Engine (1779,)
# 2019-07-23 11:40:33,172 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,173 INFO sqlalchemy.engine.base.Engine ('观澜章阁富士康北门，精装修公寓，一房一厅，拎包入住', '1280 元/月', '1室1厅1卫 43㎡ 东南向 精装修', '来自经纪人： 荣腾地产 - 荣腾地产章阁分行 - 成海华')
# 2019-07-23 11:40:33,175 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,178 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,180 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,180 INFO sqlalchemy.engine.base.Engine (1780,)
# 2019-07-23 11:40:33,183 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,184 INFO sqlalchemy.engine.base.Engine ('1号线单间，一房一厅配套齐全独立厨卫大阳台安全舒适交通便利', '1260 元/月', '1室0厅1卫 27㎡ 南向 精装修', '来自经纪人： 恒康物业 - 何登香')
# 2019-07-23 11:40:33,185 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,188 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,189 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,189 INFO sqlalchemy.engine.base.Engine (1781,)
# 2019-07-23 11:40:33,192 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,193 INFO sqlalchemy.engine.base.Engine ('房东直租 超值精装修拎包入住交通便利看房方便家私家电齐房东好', '730 元/月', '1室0厅1卫 25㎡ 南北向 精装修', '来自经纪人： 瑞驰物业 - 张迪飞')
# 2019-07-23 11:40:33,194 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,197 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,198 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,199 INFO sqlalchemy.engine.base.Engine (1782,)
# 2019-07-23 11:40:33,201 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,202 INFO sqlalchemy.engine.base.Engine ('固戍地铁站400米，精装修品牌公寓全天专人安保家电家私齐全', '1250 元/月', '1室0厅1卫 25㎡ 东南向 精装修', '来自经纪人： - 熊钰莹')
# 2019-07-23 11:40:33,204 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,207 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,208 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,208 INFO sqlalchemy.engine.base.Engine (1783,)
# 2019-07-23 11:40:33,210 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,211 INFO sqlalchemy.engine.base.Engine ('西乡固戍地铁口步行3分钟实图实价不喜勿扰', '1300 元/月', '1室0厅1卫 25㎡ 东南向 精装修', '来自经纪人： 心愿地产 - 心愿地产(固戍下围园分行) - 谢田')
# 2019-07-23 11:40:33,212 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,215 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,216 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,216 INFO sqlalchemy.engine.base.Engine (1784,)
# 2019-07-23 11:40:33,218 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,219 INFO sqlalchemy.engine.base.Engine ('单间，3号线丹竹头地铁站.超大单间，交通便利.房东直租..', '980 元/月', '1室0厅1卫 26㎡ 南北向 精装修', '来自经纪人： 御景豪庭公寓 - 姜波')
# 2019-07-23 11:40:33,220 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,225 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,227 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,229 INFO sqlalchemy.engine.base.Engine (1785,)
# 2019-07-23 11:40:33,232 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,234 INFO sqlalchemy.engine.base.Engine ('一号线固戍地铁站 超高性价比单间1100大床家电全齐', '1100 元/月', '1室0厅1卫 18㎡ 南向 精装修', '来自经纪人： 亿信达物业管理有限公司 - 黄俊雅')
# 2019-07-23 11:40:33,235 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,239 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,240 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,241 INFO sqlalchemy.engine.base.Engine (1786,)
# 2019-07-23 11:40:33,244 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,246 INFO sqlalchemy.engine.base.Engine ('三联尚品公寓，房东直租，交通方便，拎包入住，全新家私家电，', '1300 元/月', '1室0厅1卫 30㎡ 东南向 精装修', '来自经纪人： 优尚公寓 - 余海霞')
# 2019-07-23 11:40:33,247 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,251 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,251 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,252 INFO sqlalchemy.engine.base.Engine (1787,)
# 2019-07-23 11:40:33,254 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,255 INFO sqlalchemy.engine.base.Engine ('业主直租！实拍！！！牛栏前大厦附近全新公寓！', '1380 元/月', '1室0厅1卫 25㎡ 东南向 精装修', '来自经纪人： - 王超')
# 2019-07-23 11:40:33,256 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,259 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,260 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,261 INFO sqlalchemy.engine.base.Engine (1788,)
# 2019-07-23 11:40:33,264 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,265 INFO sqlalchemy.engine.base.Engine ('微棠社区公寓 24h专属客服安全保卫 精装修拎包住居住省心', '1299 元/月', '1室0厅1卫 30㎡ 南向 精装修', '来自经纪人： 美好颂自如寓 - 愿景明创(上梅林分行) - 齐少昆')
# 2019-07-23 11:40:33,267 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,270 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,271 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,271 INFO sqlalchemy.engine.base.Engine (1789,)
# 2019-07-23 11:40:33,273 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,274 INFO sqlalchemy.engine.base.Engine ('实图实价 精装修大中小单间 家具家电齐 采光好 沙井核心商圈', '1200 元/月', '1室0厅1卫 22㎡ 南北向 豪华装修', '来自经纪人： 深圳独立经纪人 - 桂行太')
# 2019-07-23 11:40:33,275 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,278 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,279 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,280 INFO sqlalchemy.engine.base.Engine (1790,)
# 2019-07-23 11:40:33,282 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,283 INFO sqlalchemy.engine.base.Engine ('三围舒适大单间，欢迎来看房', '980 元/月', '1室0厅1卫 25㎡ 南向 精装修', '来自经纪人： 深圳市皇烁物业有限公司 - 黄磊')
# 2019-07-23 11:40:33,284 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,288 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,290 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,290 INFO sqlalchemy.engine.base.Engine (1791,)
# 2019-07-23 11:40:33,294 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,295 INFO sqlalchemy.engine.base.Engine ('忍者村 连锁的品牌公寓 押一付一 家电家具全配 高品质', '1500 元/月', '1室1厅1卫 40㎡ 南向 精装修', '来自经纪人： 朗诗寓公寓 - 朱植谊')
# 2019-07-23 11:40:33,297 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,300 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,301 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,302 INFO sqlalchemy.engine.base.Engine (1792,)
# 2019-07-23 11:40:33,304 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,305 INFO sqlalchemy.engine.base.Engine ('民治 1970小镇 八号仓旁 碧桂园白领公寓 拎包入住', '1500 元/月', '1室0厅1卫 26㎡ 东南向 豪华装修', '来自经纪人： 碧家国际社区 - 碧家国际社区(深圳店) - 肖虎')
# 2019-07-23 11:40:33,306 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,309 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,310 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,310 INFO sqlalchemy.engine.base.Engine (1793,)
# 2019-07-23 11:40:33,312 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,313 INFO sqlalchemy.engine.base.Engine ('无中芥 观澜大道 兴万达广场 观澜玫瑰苑 月付优惠租', '1380 元/月', '1室1厅1卫 36㎡ 东南向 精装修', '来自经纪人： 朗诗寓公寓 - 李佳奇')
# 2019-07-23 11:40:33,315 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,318 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,319 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,320 INFO sqlalchemy.engine.base.Engine (1794,)
# 2019-07-23 11:40:33,322 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,323 INFO sqlalchemy.engine.base.Engine ('平湖直租房源!精装大套间出租!配套齐全干净舒适先到先得!', '1200 元/月', '1室0厅1卫 35㎡ 南北向 精装修', '来自经纪人： 搜鱼租房 - 搜鱼租房(固戍分行) - 刘迪爱')
# 2019-07-23 11:40:33,324 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,327 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,328 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,329 INFO sqlalchemy.engine.base.Engine (1795,)
# 2019-07-23 11:40:33,331 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,332 INFO sqlalchemy.engine.base.Engine ('双龙地铁口 全新精装公寓，单间980元，全齐出租，免介绍费', '980 元/月', '1室0厅1卫 30㎡ 南向 精装修', '来自经纪人： 房行天下地产 - 刘利良')
# 2019-07-23 11:40:33,334 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,338 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,338 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,339 INFO sqlalchemy.engine.base.Engine (1796,)
# 2019-07-23 11:40:33,342 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,342 INFO sqlalchemy.engine.base.Engine ('龙城广场地铁站 宝龙小区 复式房 精装修 带家电', '1390 元/月', '1室1厅1卫 35㎡ 南向 豪华装修', '来自经纪人： 恒康物业 - 曾文华')
# 2019-07-23 11:40:33,344 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,347 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,348 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,349 INFO sqlalchemy.engine.base.Engine (1797,)
# 2019-07-23 11:40:33,352 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,352 INFO sqlalchemy.engine.base.Engine ('全新精装公寓招租家私家电齐全可拎包入住电梯房首.次招租', '1200 元/月', '1室0厅1卫 22㎡ 南北向 精装修', '来自经纪人： 大合物业 - 徐文华')
# 2019-07-23 11:40:33,354 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,357 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,358 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,359 INFO sqlalchemy.engine.base.Engine (1798,)
# 2019-07-23 11:40:33,362 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,362 INFO sqlalchemy.engine.base.Engine ('离机场东地铁站较近 拎包入住 直租 采光好  精修公寓', '1100 元/月', '1室0厅1卫 25㎡ 南向 精装修', '来自经纪人： 泊寓租赁 - 黄晓薇')
# 2019-07-23 11:40:33,364 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,367 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,368 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,369 INFO sqlalchemy.engine.base.Engine (1799,)
# 2019-07-23 11:40:33,371 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,371 INFO sqlalchemy.engine.base.Engine ('1580秒杀固戍海滨新村精装公寓单间，直租无中介', '1580 元/月', '1室0厅1卫 28㎡ 南向 豪华装修', '来自经纪人： 招商置业 - 程常群')
# 2019-07-23 11:40:33,372 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,376 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,376 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,377 INFO sqlalchemy.engine.base.Engine (1800,)
# 2019-07-23 11:40:33,380 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,380 INFO sqlalchemy.engine.base.Engine ('急租！急租！丹竹头单间出租！配套齐全！拎包入住！非诚勿扰！！', '1380 元/月', '1室0厅1卫 18㎡ 南向 精装修', '来自经纪人： 云家商务 - 云家商务(深圳分行) - 赵瑞')
# 2019-07-23 11:40:33,382 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,386 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,387 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,388 INFO sqlalchemy.engine.base.Engine (1801,)
# 2019-07-23 11:40:33,390 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,392 INFO sqlalchemy.engine.base.Engine ('万科泊寓 交通便利 采光好通风好 带厨房  独立卫浴', '1037 元/月', '1室0厅1卫 25㎡ 南向 精装修', '来自经纪人： 泊寓租赁 - 张雲晏')
# 2019-07-23 11:40:33,394 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,397 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,398 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,398 INFO sqlalchemy.engine.base.Engine (1802,)
# 2019-07-23 11:40:33,400 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,401 INFO sqlalchemy.engine.base.Engine ('无中介 7月免租 免管理费 拎包入住南山科技园 5号线民治站', '1580 元/月', '1室1厅1卫 48㎡ 东南向 精装修', '来自经纪人： 深圳房产经纪 - 万振亚')
# 2019-07-23 11:40:33,403 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,406 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,406 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,407 INFO sqlalchemy.engine.base.Engine (1803,)
# 2019-07-23 11:40:33,410 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,410 INFO sqlalchemy.engine.base.Engine ('佳兆业白领公寓  8折大放送  押一付一  近地铁白石龙站', '1450 元/月', '1室0厅1卫 23㎡ 南向 精装修', '来自经纪人： 佳兆业 - 陈观云')
# 2019-07-23 11:40:33,411 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,415 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,415 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,416 INFO sqlalchemy.engine.base.Engine (1804,)
# 2019-07-23 11:40:33,419 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,419 INFO sqlalchemy.engine.base.Engine ('一号线固戍地铁站采光一流海景房房间1400装修好格局好', '1400 元/月', '1室0厅1卫 26㎡ 南向 精装修', '来自经纪人： Z+逐梦空间 - Z+逐梦空间(洪浪北分行) - 修学龙')
# 2019-07-23 11:40:33,421 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,424 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,425 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,426 INFO sqlalchemy.engine.base.Engine (1805,)
# 2019-07-23 11:40:33,427 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,428 INFO sqlalchemy.engine.base.Engine ('南园枫叶公寓 全新装修 全新家私家电 近地铁口 周边配套齐全', '4800 元/月', '2室2厅1卫 66㎡ 东南向 精装修', '来自经纪人： 裕丰地产 - 裕丰地产鸿瑞分行 - 车轩')
# 2019-07-23 11:40:33,430 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,433 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,434 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,435 INFO sqlalchemy.engine.base.Engine (1806,)
# 2019-07-23 11:40:33,438 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,439 INFO sqlalchemy.engine.base.Engine ('东门 一品东门雅园 精装二房 看房有钥匙 近地铁站 东方颐园', '5500 元/月', '2室2厅1卫 65㎡ 东南向 精装修', '来自经纪人： 裕丰地产 - 深圳裕丰房地产销售代理有限公司(东门168分行) - 蒙奇')
# 2019-07-23 11:40:33,440 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,444 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,445 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,446 INFO sqlalchemy.engine.base.Engine (1807,)
# 2019-07-23 11:40:33,449 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,449 INFO sqlalchemy.engine.base.Engine ('蛇口壹栈公寓壹间 全新精装2房 带电，官网直租 免拥代理', '7288 元/月', '2室2厅1卫 72㎡ 南向 精装修', '来自经纪人： 深圳市华创房地产投资顾问有限公司 - 华创地产海韵嘉园分行 - 戴国龙')
# 2019-07-23 11:40:33,451 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,454 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,455 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,455 INFO sqlalchemy.engine.base.Engine (1808,)
# 2019-07-23 11:40:33,458 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,459 INFO sqlalchemy.engine.base.Engine ('南岭锦绣山庄高楼层光线超好价钱实惠', '3500 元/月', '3室2厅2卫 120㎡ 东北向 精装修', '来自经纪人： 家家世纪 - 家家世纪(南岭分行) - 刘波')
# 2019-07-23 11:40:33,461 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,463 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,464 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,465 INFO sqlalchemy.engine.base.Engine (1809,)
# 2019-07-23 11:40:33,468 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,469 INFO sqlalchemy.engine.base.Engine ('木棉湾站精装2包  拎包入住。8月1日可以住', '3600 元/月', '2室2厅1卫 75㎡ 东北向 精装修', '来自经纪人： Q房网 - Q房网茂业城分行 - 周春娣')
# 2019-07-23 11:40:33,470 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,473 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,473 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,474 INFO sqlalchemy.engine.base.Engine (1810,)
# 2019-07-23 11:40:33,476 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,477 INFO sqlalchemy.engine.base.Engine ('精装一房一厅，适合情侣居住，带家私家电，环境优雅，拎包入住', '1350 元/月', '1室0厅1卫 20㎡ 南北向 豪华装修', '来自经纪人： 蚂蚁物业 - 赖珍琼')
# 2019-07-23 11:40:33,478 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,482 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,483 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,484 INFO sqlalchemy.engine.base.Engine (1811,)
# 2019-07-23 11:40:33,487 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,488 INFO sqlalchemy.engine.base.Engine ('深大附近精装两房，业主精装', '5800 元/月', '2室2厅0卫 38.04㎡ 南北向 简单装修', '来自经纪人： 乐有家地产 - 黄景崇')
# 2019-07-23 11:40:33,490 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,493 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,494 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,494 INFO sqlalchemy.engine.base.Engine (1812,)
# 2019-07-23 11:40:33,497 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,497 INFO sqlalchemy.engine.base.Engine ('五和地铁站B出口200米 大小单间一房一厅超大阳台 可短租', '1200 元/月', '1室0厅1卫 29㎡ 西北向 精装修', '来自经纪人： 深圳房产经纪 - 深圳房产经纪22 - 周秀龙')
# 2019-07-23 11:40:33,499 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,501 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,502 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,503 INFO sqlalchemy.engine.base.Engine (1813,)
# 2019-07-23 11:40:33,505 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,506 INFO sqlalchemy.engine.base.Engine ('精装电梯公寓， 光线好， 家私家电齐，  大阳台，采光通风好', '1380 元/月', '1室0厅1卫 20㎡ 南北向 精装修', '来自经纪人： 蚂蚁物业 - 赖珍琼')
# 2019-07-23 11:40:33,507 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,510 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,511 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,511 INFO sqlalchemy.engine.base.Engine (1814,)
# 2019-07-23 11:40:33,513 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,514 INFO sqlalchemy.engine.base.Engine ('希尔顿酒店旁酒店式公寓 停车方便装修好 福田岗厦', '9000 元/月', '2室2厅1卫 81㎡ 东向 豪华装修', '来自经纪人： 美联物业 - 美联物业彩田分行 - 杨艳')
# 2019-07-23 11:40:33,515 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,518 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,520 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,521 INFO sqlalchemy.engine.base.Engine (1815,)
# 2019-07-23 11:40:33,524 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,525 INFO sqlalchemy.engine.base.Engine ('艺术大厦 2室2厅1卫', '3680 元/月', '2室2厅1卫 80㎡ 东南向', '来自个人房源：侯先生')
# 2019-07-23 11:40:33,527 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,530 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,531 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,532 INFO sqlalchemy.engine.base.Engine (1816,)
# 2019-07-23 11:40:33,536 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,537 INFO sqlalchemy.engine.base.Engine ('民治地铁站，全新私家，电梯房，随时看房，随时拎包入住免中费', '1280 元/月', '1室0厅1卫 28㎡ 西南向 精装修', '来自经纪人： 深圳房产经纪 - 深圳房产经纪60 - 兰雪雯')
# 2019-07-23 11:40:33,538 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,541 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,542 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,543 INFO sqlalchemy.engine.base.Engine (1817,)
# 2019-07-23 11:40:33,545 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,545 INFO sqlalchemy.engine.base.Engine ('龙东社区.单身情侣酒店式电梯公寓诚信招租.环境好带阳台好停车', '600 元/月', '1室0厅1卫 28㎡ 南北向 精装修', '来自经纪人： 中润家物业 - 张政')
# 2019-07-23 11:40:33,547 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,550 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,551 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,552 INFO sqlalchemy.engine.base.Engine (1818,)
# 2019-07-23 11:40:33,555 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,556 INFO sqlalchemy.engine.base.Engine ('地铁11号线塘尾站（直达福永南山）配置齐全拎包入住', '680 元/月', '1室0厅1卫 21㎡ 南北向 精装修', '来自经纪人： - 燕钢')
# 2019-07-23 11:40:33,557 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,560 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,561 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,562 INFO sqlalchemy.engine.base.Engine (1819,)
# 2019-07-23 11:40:33,564 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,565 INFO sqlalchemy.engine.base.Engine ('直租 精装公寓 家私家电齐全  阳光大单间 干净卫生专人管理', '800 元/月', '1室0厅1卫 30㎡ 南向 精装修', '来自经纪人： - 肖礼')
# 2019-07-23 11:40:33,566 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,569 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,570 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,571 INFO sqlalchemy.engine.base.Engine (1820,)
# 2019-07-23 11:40:33,573 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,574 INFO sqlalchemy.engine.base.Engine ('业主出租！全新精装复式公寓', '2500 元/月', '1室1厅1卫 45㎡ 南北向 精装修', '来自经纪人： 中润永利 - 姜治国')
# 2019-07-23 11:40:33,575 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,578 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,579 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,579 INFO sqlalchemy.engine.base.Engine (1821,)
# 2019-07-23 11:40:33,583 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,583 INFO sqlalchemy.engine.base.Engine ('房东直租 康扬创客谷精装loft公寓，依山伴水，拎包入住', '1980 元/月', '1室1厅1卫 45㎡ 南北向 精装修', '来自经纪人： 中润永利 - 姜治国')
# 2019-07-23 11:40:33,585 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,588 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,590 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,591 INFO sqlalchemy.engine.base.Engine (1822,)
# 2019-07-23 11:40:33,594 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,595 INFO sqlalchemy.engine.base.Engine ('灵芝地铁口 水口花园精装公寓 复式楼一房一厅 两房一厅采光好', '1400 元/月', '1室1厅1卫 45㎡ 南北向 精装修', '来自经纪人： 永利公寓物业管理 - 朱炫')
# 2019-07-23 11:40:33,596 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,599 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,600 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,601 INFO sqlalchemy.engine.base.Engine (1823,)
# 2019-07-23 11:40:33,606 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,607 INFO sqlalchemy.engine.base.Engine ('六约 独栋品牌公寓 停车场 综合公区 拎包入住 配备保洁保安', '1200 元/月', '1室0厅1卫 28㎡ 南北向 精装修', '来自经纪人： 恒康物业 - 陆忠炜')
# 2019-07-23 11:40:33,608 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,611 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,611 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,613 INFO sqlalchemy.engine.base.Engine (1824,)
# 2019-07-23 11:40:33,615 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,616 INFO sqlalchemy.engine.base.Engine ('整租 4号线白石龙地铁站 精装电梯房 家私齐全 采光好可做法', '950 元/月', '1室0厅1卫 27㎡ 南北向 精装修', '来自经纪人： 俊辉物业 - 代逢平')
# 2019-07-23 11:40:33,617 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,620 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,620 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,621 INFO sqlalchemy.engine.base.Engine (1825,)
# 2019-07-23 11:40:33,623 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,624 INFO sqlalchemy.engine.base.Engine ('松岗益安居 1室0厅1卫', '980 元/月', '1室0厅1卫 28㎡ 南北向', '来自个人房源：张先生')
# 2019-07-23 11:40:33,626 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,628 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,629 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,630 INFO sqlalchemy.engine.base.Engine (1826,)
# 2019-07-23 11:40:33,632 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,633 INFO sqlalchemy.engine.base.Engine ('新出精装大三房，朝南看花园泳池，景观棒，绿化好，物业负责安心', '5300 元/月', '3室2厅1卫 85㎡ 南向 精装修', '来自经纪人： 乐有家地产 - 乐有家地产尚水天成分行 - 何根权')
# 2019-07-23 11:40:33,635 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,638 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,639 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,640 INFO sqlalchemy.engine.base.Engine (1827,)
# 2019-07-23 11:40:33,641 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,642 INFO sqlalchemy.engine.base.Engine ('知音文创产业园 章阁科技园 超大公区 押一付一 拎包入住', '700 元/月', '1室1厅1卫 20㎡ 南向 精装修', '来自经纪人： 冠寓 - 冠寓(新安分行) - 李颖')
# 2019-07-23 11:40:33,643 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,646 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,647 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,648 INFO sqlalchemy.engine.base.Engine (1828,)
# 2019-07-23 11:40:33,650 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,651 INFO sqlalchemy.engine.base.Engine ('碧桂园精装一房 近地铁无中介 家私家电网络齐全 厨房健身房', '1500 元/月', '1室1厅1卫 30㎡ 东南向 精装修', '来自经纪人： 碧家国际社区 - 碧家国际社区(深圳店) - 冷怡豪')
# 2019-07-23 11:40:33,653 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,655 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,656 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,657 INFO sqlalchemy.engine.base.Engine (1829,)
# 2019-07-23 11:40:33,659 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,660 INFO sqlalchemy.engine.base.Engine ('倍利得电子科技观澜工业园 全新精装家电齐全 拎包入住', '650 元/月', '1室0厅1卫 20㎡ 南向 精装修', '来自经纪人： 冠寓 - 李颖')
# 2019-07-23 11:40:33,661 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,665 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,666 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:40:33,667 INFO sqlalchemy.engine.base.Engine (1830,)
# 2019-07-23 11:40:33,669 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:40:33,670 INFO sqlalchemy.engine.base.Engine ('硅谷动力产业园 毕业生每月200京东卡 精装 押一付一', '650 元/月', '1室1厅1卫 20㎡ 东南向 精装修', '来自经纪人： 冠寓 - 李颖')
# 2019-07-23 11:40:33,671 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:40:33,674 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:40:33,675 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# ...
# 2019-07-23 11:41:33,129 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,138 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,141 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,142 INFO sqlalchemy.engine.base.Engine (4391,)
# 2019-07-23 11:41:33,148 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,150 INFO sqlalchemy.engine.base.Engine ('麒麟名都大型花园小区 精装两房全齐出租 可随时看房', '3300 元/月', '2室1厅1卫 84㎡ 南北向 豪华装修', '来自经纪人： - 张蓉')
# 2019-07-23 11:41:33,154 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,162 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,164 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,166 INFO sqlalchemy.engine.base.Engine (4392,)
# 2019-07-23 11:41:33,174 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,176 INFO sqlalchemy.engine.base.Engine ('平山村 1室0厅1卫', '1750 元/月', '1室0厅1卫 25㎡ 南向', '来自个人房源：罗先生')
# 2019-07-23 11:41:33,180 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,188 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,191 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,194 INFO sqlalchemy.engine.base.Engine (4393,)
# 2019-07-23 11:41:33,201 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,203 INFO sqlalchemy.engine.base.Engine ('科苑西住宅小区 2室2厅1卫', '6600 元/月', '2室2厅1卫 75㎡ 南向', '来自个人房源：余先生')
# 2019-07-23 11:41:33,210 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,219 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,223 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,226 INFO sqlalchemy.engine.base.Engine (4394,)
# 2019-07-23 11:41:33,235 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,237 INFO sqlalchemy.engine.base.Engine ('水口花园 1室0厅1卫', '1500 元/月', '1室0厅1卫 30㎡ 南向', '来自个人房源：张志豪先生')
# 2019-07-23 11:41:33,242 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,253 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,257 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,258 INFO sqlalchemy.engine.base.Engine (4395,)
# 2019-07-23 11:41:33,265 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,269 INFO sqlalchemy.engine.base.Engine ('金源工业区 1室1厅1卫', '1300 元/月', '1室1厅1卫 40㎡ 南北向', '来自个人房源：王先生')
# 2019-07-23 11:41:33,274 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,287 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,290 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,292 INFO sqlalchemy.engine.base.Engine (4396,)
# 2019-07-23 11:41:33,300 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,303 INFO sqlalchemy.engine.base.Engine ('租房立省4000元前海花园精装好房 先到先得  月付', '2830 元/月', '1室0厅1卫 14㎡ 北向 精装修', '来自经纪人： 云家商务 - 云家商务(深圳分行) - 林洋')
# 2019-07-23 11:41:33,307 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,315 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,318 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,320 INFO sqlalchemy.engine.base.Engine (4397,)
# 2019-07-23 11:41:33,330 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,332 INFO sqlalchemy.engine.base.Engine ('双地铁带飘窗厅卧一体 品牌公寓直租 配套齐全 1个月起租', '2500 元/月', '1室0厅1卫 28.00㎡ 东南向 精装修', '来自经纪人： 乐有家地产 - 乐有家地产棕榈堡二分行 - 钟怡云')
# 2019-07-23 11:41:33,336 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,345 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,349 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,351 INFO sqlalchemy.engine.base.Engine (4398,)
# 2019-07-23 11:41:33,356 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,358 INFO sqlalchemy.engine.base.Engine ('西丽珠光站口 安静小区 龙辉花园 精装三房 采光好 随时入住', '5800 元/月', '3室2厅1卫 87.00㎡ 南向 精装修', '来自经纪人： 好房网地产 - 好房网地产(南国丽城分行) - 尹华强')
# 2019-07-23 11:41:33,362 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,380 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,384 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,387 INFO sqlalchemy.engine.base.Engine (4399,)
# 2019-07-23 11:41:33,395 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,399 INFO sqlalchemy.engine.base.Engine ('固戍精装大两房一厅75平超大空间 直租无中介可居家和宿舍', '2800 元/月', '2室1厅1卫 85㎡ 东南向 精装修', '来自经纪人： 租云物业 - 彭德胜')
# 2019-07-23 11:41:33,402 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,410 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,414 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,417 INFO sqlalchemy.engine.base.Engine (4400,)
# 2019-07-23 11:41:33,427 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,429 INFO sqlalchemy.engine.base.Engine ('西乡 鸿隆广场(港隆城） 2室1厅', '4000 元/月', '2室1厅1卫 48㎡ 西南向 精装修', '来自经纪人： 独立经纪人（龙华） - 傅俊镇')
# 2019-07-23 11:41:33,435 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,444 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,447 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,450 INFO sqlalchemy.engine.base.Engine (4401,)
# 2019-07-23 11:41:33,455 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,458 INFO sqlalchemy.engine.base.Engine ('熙璟城精装三房，业主自住房，配套成熟商业，', '5000 元/月', '3室2厅1卫 85㎡ 东南向 精装修', '来自经纪人： 中原地产 - 林志安')
# 2019-07-23 11:41:33,463 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,476 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,483 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,486 INFO sqlalchemy.engine.base.Engine (4402,)
# 2019-07-23 11:41:33,494 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,496 INFO sqlalchemy.engine.base.Engine ('布吉丹竹头 豪华情侣大单间 独立厨卫 拎包入住 可停车', '1000 元/月', '1室0厅1卫 28㎡ 南北向 豪华装修', '来自经纪人： - 陈明祥')
# 2019-07-23 11:41:33,502 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,510 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,512 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,514 INFO sqlalchemy.engine.base.Engine (4403,)
# 2019-07-23 11:41:33,523 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,527 INFO sqlalchemy.engine.base.Engine ('村前路 1室0厅1卫', '550 元/月', '1室0厅1卫 28㎡ 南向', '来自个人房源：方先生')
# 2019-07-23 11:41:33,532 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,542 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,546 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,551 INFO sqlalchemy.engine.base.Engine (4404,)
# 2019-07-23 11:41:33,561 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,563 INFO sqlalchemy.engine.base.Engine ('整租  四号线龙胜地铁站  三号线丹竹头  房源采光好通风好', '970 元/月', '1室0厅1卫 22㎡ 南北向 精装修', '来自经纪人： 众合物业 - 熊贤徽')
# 2019-07-23 11:41:33,569 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,584 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,591 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,594 INFO sqlalchemy.engine.base.Engine (4405,)
# 2019-07-23 11:41:33,602 INFO sqlalchemy.engine.base.Engine INSERT INTO rental (title, price, info, agent) VALUES (?, ?, ?, ?)
# 2019-07-23 11:41:33,607 INFO sqlalchemy.engine.base.Engine ('桃源居11区，双龙抱珠户型，采光好南北通，位置安静，拎包入住', '7500 元/月', '4室2厅2卫 138㎡ 南向 精装修', '来自经纪人： Q房网 - Q房网桃源盛景分行 - 房浩')
# 2019-07-23 11:41:33,616 INFO sqlalchemy.engine.base.Engine COMMIT
# 2019-07-23 11:41:33,625 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-07-23 11:41:33,628 INFO sqlalchemy.engine.base.Engine SELECT rental.id AS rental_id, rental.title AS rental_title, rental.price AS rental_price, rental.info AS rental_info, rental.agent AS rental_agent
# FROM rental
# WHERE rental.id = ?
# 2019-07-23 11:41:33,632 INFO sqlalchemy.engine.base.Engine (4406,)
# http://sz.ganji.com/zufang/pn18 status: 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-69fd00a29007> in <module>()
#      23 for num in range(71):
#      24     re_url = base_url.format(num)
# ---> 25     response = requests.get(re_url, headers = headers)
#      26     if response.status_code == 403:
#      27         for i in range(3):
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     656
#     657         if not stream:
# --> 658             r.content
#     659
#     660         return r
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in content(self)
#     821                 self._content = None
#     822             else:
# --> 823                 self._content = bytes().join(self.iter_content(CONTENT_CHUNK_SIZE)) or bytes()
#     824
#     825         self._content_consumed = True
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     599                 if self.chunk_left == 0:
#     600                     break
# --> 601                 chunk = self._handle_chunk(amt)
#     602                 decoded = self._decode(chunk, decode_content=decode_content,
#     603                                        flush_decoder=False)
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     564             returned_chunk = value
#     565         else:  # amt > self.chunk_left
# --> 566             returned_chunk = self._fp._safe_read(self.chunk_left)
#     567             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     568             self.chunk_left = None
#
# ~/anaconda3/lib/python3.6/http/client.py in _safe_read(self, amt)
#     610         s = []
#     611         while amt > 0:
# --> 612             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     613             if not chunk:
#     614                 raise IncompleteRead(b''.join(s), amt)
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
